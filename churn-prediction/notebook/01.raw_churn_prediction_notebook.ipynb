# %%
# Ler o CSV com Spark

df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Volumes/architect_company/churn_prediction/1_raw/customer_churn_dataset-testing-master.csv")

display(df)

# %%
# Salvar como Delta Table

from pyspark.sql.functions import col

df_cleaned = df
for column in df.columns:
    df_cleaned = df_cleaned.withColumnRenamed(column, column.replace(" ", "_").lower())

df_cleaned.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable(
        "architect_company.churn_prediction.customer_churn"
    )

# %%
# Consultar com SQL

# %sql
SELECT *
FROM architect_company.churn_prediction.customer_churn
LIMIT 10;

# %%
# Count em SQL
# %sql
SELECT count(*) FROM architect_company.churn_prediction.customer_churn
